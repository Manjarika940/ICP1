# %% [markdown]
# # Matplotlib Practice
#
# This notebook offers a set of exercises to different tasks with Matplotlib.
#
# It should be noted there may be more than one different way to answer a question or complete an exercise.
#
# Different tasks will be detailed by comments or text.
#
# For further reference and resources, it's advised to check out the [Matplotlib documentation](https://matplotlib.org/3.1.1/contents.html).
#
# If you're stuck, don't forget, you can always search for a function, for example if you want to create a plot with `plt.subplots()`, search for [`plt.subplots()`](https://www.google.com/search?q=plt.subplots()).

# %%
# Import the pyplot module from matplotlib as plt and make sure
# plots appear in the notebook using '%matplotlib inline'
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a simple plot using plt.plot()
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 8, 7]

# Create a basic line plot
plt.plot(x, y)

# Add title and labels
plt.title("Simple Line Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")

# Show the plot
plt.show()

# %%
# Plot a single Python list
import matplotlib.pyplot as plt

# A single Python list
data = [3, 7, 1, 5, 9]

# Plotting the list
plt.plot(data)

# Add title and labels
plt.title("Plot of a Single List")
plt.xlabel("Index")
plt.ylabel("Value")

# Show the plot
plt.show()

# %%
# Create two lists, one called X, one called y, each with 5 numbers in them
# Create two Python lists
X = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

# Display the lists
print("X =", X)
print("y =", y)
# Out:
# X = [1, 2, 3, 4, 5]
# y = [10, 20, 25, 30, 40]

# %%
# Plot X & y (the lists you've created)
import matplotlib.pyplot as plt
# X and y lists
X = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

# Plotting X vs y
plt.plot(X, y)

# Add title and axis labels
plt.title("Line Plot of X vs y")
plt.xlabel("X values")
plt.ylabel("Y values")

# Show the plot
plt.show()

# %% [markdown]
# There's another way to create plots with Matplotlib, it's known as the object-orientated (OO) method. Let's try it.

# %%
# Create a plot using plt.subplots()
import matplotlib.pyplot as plt

# Create a figure and axes using the OO method
fig, ax = plt.subplots()

# Data to plot
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

# Plot the data on the axes
ax.plot(x, y)

# Set title and labels using the axes object
ax.set_title("OO Method Plot")
ax.set_xlabel("X values")
ax.set_ylabel("Y values")

# Show the plot
plt.show()

# %%
|# Create a plot using plt.subplots() and then add X & y on the axes
import matplotlib.pyplot as plt

# Data lists
X = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

# Create a figure and axes
fig, ax = plt.subplots()

# Plot X and y on the axes
ax.plot(X, y)

# Add labels and title
ax.set_title("Plot using plt.subplots()")
ax.set_xlabel("X values")
ax.set_ylabel("Y values")

# Display the plot
plt.show()
# Out:
#   File "/tmp/ipython-input-156-3399499078.py", line 1
#     |# Create a plot using plt.subplots() and then add X & y on the axes
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# Now let's try a small matplotlib workflow.

# %%
# Import and get matplotlib ready
import matplotlib.pyplot as plt


# Prepare data (create two lists of 5 numbers, X & y)
# Create X and y data lists
X = [1, 2, 3, 4, 5]
y = [5, 10, 15, 10, 5]


# Setup figure and axes using plt.subplots()
fig, ax = plt.subplots()

# Add data (X, y) to axes
ax.plot(X, y)

# Customize plot by adding a title, xlabel and ylabel
ax.set_title("Sample Line Plot")
ax.set_xlabel("X Axis Label")
ax.set_ylabel("Y Axis Label")

# Save the plot to file using fig.savefig()
# Save the current figure to a file
fig.savefig("my_plot.png")

# %% [markdown]
# Okay, this is a simple line plot, how about something a little different?
#
# To help us, we'll import NumPy.

# %%
# Import NumPy as np
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.linspace(0, 100, 100)

print(X)
# Out:
# [  0.           1.01010101   2.02020202   3.03030303   4.04040404
#    5.05050505   6.06060606   7.07070707   8.08080808   9.09090909
#   10.1010101   11.11111111  12.12121212  13.13131313  14.14141414
#   15.15151515  16.16161616  17.17171717  18.18181818  19.19191919
#   20.2020202   21.21212121  22.22222222  23.23232323  24.24242424
#   25.25252525  26.26262626  27.27272727  28.28282828  29.29292929
#   30.3030303   31.31313131  32.32323232  33.33333333  34.34343434
#   35.35353535  36.36363636  37.37373737  38.38383838  39.39393939
#   40.4040404   41.41414141  42.42424242  43.43434343  44.44444444
#   45.45454545  46.46464646  47.47474747  48.48484848  49.49494949
#   50.50505051  51.51515152  52.52525253  53.53535354  54.54545455
#   55.55555556  56.56565657  57.57575758  58.58585859  59.5959596
#   60.60606061  61.61616162  62.62626263  63.63636364  64.64646465
#   65.65656566  66.66666667  67.67676768  68.68686869  69.6969697
#   70.70707071  71.71717172  72.72727273  73.73737374  74.74747475
#   75.75757576  76.76767677  77.77777778  78.78787879  79.7979798
#   80.80808081  81.81818182  82.82828283  83.83838384  84.84848485
#   85.85858586  86.86868687  87.87878788  88.88888889  89.8989899
#   90.90909091  91.91919192  92.92929293  93.93939394  94.94949495
#   95.95959596  96.96969697  97.97979798  98.98989899 100.        ]

# %%
# Create an array of 100 evenly spaced numbers between 0 and 100 using NumPy and save it to variable X
ax.plot(X, X**2)

# %% [markdown]
# We'll start with scatter plots.

# %%
# Create a scatter plot of X versus the exponential of X (np.exp(X))
ax.scatter(X, np.exp(X))

# %%
# Create a scatter plot of X versus np.sin(X)
ax.scatter(X, np.sin(X))

# %% [markdown]
# How about we try another type of plot? This time let's look at a bar plot. First we'll make some data.

# %%
# Create a Python dictionary of 3 of your favourite foods with
# The keys of the dictionary should be the food name and the values their price
favorite_foods = {
    "Pizza": 12.99,
    "Sushi": 18.50,
    "Ice Cream": 6.75
}

# %%
# Create a bar graph where the x-axis is the keys of the dictionary
# and the y-axis is the values of the dictionary
ax.bar(favorite_foods.keys(), favorite_foods.values())

ax.set_title("Prices of Favorite Foods")

# Add a title, xlabel and ylabel to the plot
ax.set_xlabel("Food")
ax.set_ylabel("Price ($)")
# Out:
# Text(25.0, 0.5, 'Price ($)')

# %%
# Make the same plot as above, except this time make the bars go horizontal
ax.barh(favorite_foods.keys(), favorite_foods.values())
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# All this food plotting is making me hungry. But we've got a couple of plots to go.
#
# Let's see a histogram.

# %%
# Create 1000 normally distributed random numbers
X = np.random.randn(1000)


# Create a histogram plot of X
ax.hist(X)
# Out:
# (array([ 15.,  39.,  94., 185., 225., 223., 140.,  55.,  18.,   6.]),
#  array([-2.90812956, -2.29237536, -1.67662116, -1.06086696, -0.44511276,
#          0.17064144,  0.78639564,  1.40214984,  2.01790404,  2.63365824,
#          3.24941244]),
#  <BarContainer object of 10 artists>)

# %%
# Create a NumPy array of 1000 random numbers and save it to X
X = np.random.rand(1000)



# Create a histogram plot of X
ax.hist(X)
# Out:
# (array([ 75.,  90., 108.,  93., 102., 120., 106., 105.,  99., 102.]),
#  array([2.68930184e-04, 1.00200198e-01, 2.00131466e-01, 3.00062734e-01,
#         3.99994002e-01, 4.99925270e-01, 5.99856538e-01, 6.99787806e-01,
#         7.99719074e-01, 8.99650342e-01, 9.99581610e-01]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Notice how the distributions (spread of data) are different. Why do they differ?
#
#
# Now let's try make some subplots. A subplot is another name for a figure with multiple plots on it.

# %%
# Create an empty subplot with 2 rows and 2 columns (4 subplots total)
fig, axs = plt.subplots(2, 2)

# %% [markdown]
# Notice how the subplot has multiple figures. Now let's add data to each axes.

# %%
# Create the same plot as above with 2 rows and 2 columns and figsize of (10, 5)
fig, axs = plt.subplots(2, 2, figsize=(10, 5))



# Plot X versus X/2 on the top left axes
axs[0, 0].plot(X, X / 2)

# Plot a scatter plot of 10 random numbers on each axis on the top right subplot
axs[0, 1].scatter(np.random.rand(10), np.random.rand(10))

# Plot a bar graph of the favourite food keys and values on the bottom left subplot
axs[1, 0].bar(favorite_foods.keys(), favorite_foods.values())



# Plot a histogram of 1000 random normally distributed numbers on the bottom right subplot
axs[1, 1].hist(np.random.randn(1000))
# Out:
# (array([ 15.,  50., 100., 216., 255., 192., 116.,  41.,  14.,   1.]),
#  array([-2.69840128, -2.09689711, -1.49539295, -0.89388879, -0.29238462,
#          0.30911954,  0.9106237 ,  1.51212787,  2.11363203,  2.7151362 ,
#          3.31664036]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Now we've seen how to plot with Matplotlib and data directly.
#
# First we'll need to import pandas and create a DataFrame work with.

# %%
# Import pandas as pd
import pandas as pd

# %%
# Import the '../data/car-sales.csv' into a DataFame called car_sales and view
car_sales = pd.read_csv('/content/car-sales (1).csv')

# %%
# Try to plot the 'Price' column using the plot() function
car_sales['Price'] = car_sales['Price'].replace('[\$,]', '', regex=True).astype(float)
car_sales['Price'].plot()
# Out:
# <Axes: >

# %% [markdown]
# Why doesn't it work?
#
# Hint: It's not numeric data.
#
# In the process of turning it to numeric data, let's create another column which adds the total amount of sales and another one which shows what date the car was sold.
#
# Hint: To add a column up cumulatively, look up the cumsum() function. And to create a column of dates, look up the date_range() function.

# %%
# Remove the symbols, the final two numbers from the 'Price' column and convert it to numbers
# Convert all values in 'Price' to string first
car_sales['Price'] = car_sales['Price'].astype(str)

# Remove '$' and ',' symbols
car_sales['Price'] = car_sales['Price'].str.replace('[\$,]', '', regex=True)

# Remove last two characters
car_sales['Price'] = car_sales['Price'].str.slice(0, -2)


# Convert to numeric
car_sales['Price'] = pd.to_numeric(car_sales['Price'], errors='coerce')

# Drop rows with NaN in 'Price' column
car_sales.dropna(subset=['Price'], inplace=True)

# %%
# Add a column called 'Total Sales' to car_sales which cumulatively adds the 'Price' column
car_sales['Total Sales'] = car_sales['Price'].cumsum()



# Add a column called 'Sale Date' which lists a series of successive dates starting from today (your today)
car_sales['Sale Date'] = pd.date_range(start=pd.Timestamp.today().normalize(), periods=len(car_sales), freq='D')

# View the car_sales DataFrame
print(car_sales)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales  Sale Date
# 0  Toyota  White         150043      4   4000         4000 2025-07-15
# 1   Honda    Red          87899      4   5000         9000 2025-07-16
# 2  Toyota   Blue          32549      3   7000        16000 2025-07-17
# 3     BMW  Black          11179      5  22000        38000 2025-07-18
# 4  Nissan  White         213095      4   3500        41500 2025-07-19
# 5  Toyota  Green          99213      4   4500        46000 2025-07-20
# 6   Honda   Blue          45698      4   7500        53500 2025-07-21
# 7   Honda   Blue          54738      4   7000        60500 2025-07-22
# 8  Toyota  White          60000      4   6250        66750 2025-07-23
# 9  Nissan  White          31600      4   9700        76450 2025-07-24

# %% [markdown]
# Now we've got a numeric column (`Total Sales`) and a dates column (`Sale Date`), let's visualize them.

# %%
# Use the plot() function to plot the 'Sale Date' column versus the 'Total Sales' column
car_sales.plot(x='Sale Date', y='Total Sales')
# Out:
# <Axes: xlabel='Sale Date'>

# %%
#Convert the 'Price' column to the integers
car_sales['Price'] =  car_sales['Price'].astype(int)


# Create a scatter plot of the 'Odometer (KM)' and 'Price' column using the plot() function
car_sales.plot(kind='scatter', x='Odometer (KM)', y='Price')
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
# Create a NumPy array of random numbers of size (10, 4) and save it to X
import numpy as np

X = np.random.rand(10, 4)


# Turn the NumPy array X into a DataFrame with columns called ['a', 'b', 'c', 'd']
df = pd.DataFrame(X, columns=['a', 'b', 'c', 'd'])


# Create a bar graph of the DataFrame
df.plot.bar()
# Out:
# <Axes: >

# %%
# Create a bar graph of the 'Make' and 'Odometer (KM)' columns in the car_sales DataFrame
car_sales.plot.bar(x='Make', y='Odometer (KM)')
# Out:
# <Axes: xlabel='Make'>

# %%
# Create a histogram of the 'Odometer (KM)' column
car_sales['Odometer (KM)'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Create a histogram of the 'Price' column with 20 bins
car_sales['Price'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Now we've seen a few examples of plotting directly from DataFrames using the `car_sales` dataset.
#
# Let's try using a different dataset.

# %%
# Import "../data/heart-disease.csv" and save it to the variable "heart_disease"
import pandas as pd

heart_disease = pd.read_csv("/content/heart-disease (1).csv")

# %%
# View the first 10 rows of the heart_disease DataFrame
print(heart_disease.head(10))
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
# 7   0     3       1
# 8   0     3       1
# 9   0     2       1

# %%
# Create a histogram of the "age" column with 50 bins
heart_disease['age'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Call plot.hist() on the heart_disease DataFrame and toggle the
# "subplots" parameter to True
heart_disease.plot.hist(subplots=True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# That plot looks pretty squished. Let's change the figsize.

# %%
# Call the same line of code from above except change the "figsize" parameter
# to be (10, 30)
heart_disease.plot.hist(subplots=True, figsize=(10, 30))
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# Now let's try comparing two variables versus the target variable.
#
# More specifially we'll see how age and cholesterol combined effect the target in **patients over 50 years old**.
#
# For this next challenge, we're going to be replicating the plot1:

# %%
print(heart_disease.columns)
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# Replicate the above plot in whichever way you see fit

# Note: The method below is only one way of doing it, yours might be
# slightly different

# Create DataFrame with patients over 50 years old
patients_over_50 = heart_disease[heart_disease['age'] > 50]


# Create the plot
subset = heart_disease[heart_disease['age'] > 50]






# Plot the data
plt.scatter(subset['age'], subset['chol'], c=subset['target'], cmap='bwr', alpha=0.7)


# Customize the plot
plt.xlabel('Age')
plt.ylabel('chol')
plt.title('Age vs chol colored by Target (patients > 50)')
plt.colorbar(label='Target')



# Add a meanline
mean_chol = patients_over_50['chol'].mean()
plt.axhline(mean_chol, color='green', linestyle='--', label='Mean Cholesterol')
mean_age = patients_over_50['age'].mean()
plt.axvline(mean_age, color='orange', linestyle='--', label='Mean Age')
plt.legend()
plt.show()

# %% [markdown]
# Now you've created a plot of two different variables, let's change the style.

# %%
# Check what styles are available under plt
plt.style.use('ggplot')  # Or any other style from the list

# %%
# Change the style to use "seaborn-whitegrid"
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# Now the style has been changed, we'll replot the same figure from above and see what it looks like.
#
# If you've changed the style correctly, it should look like plot2

# %%
# Reproduce the same figure as above with the "seaborn-whitegrid" style
plt.style.use('seaborn-v0_8-whitegrid')
# Create the plot
plt.figure(figsize=(10, 6))


# Plot the data
plt.scatter(
    patients_over_50['age'],
    patients_over_50['chol'],
    c=patients_over_50['target'],
    cmap='bwr',
    alpha=0.7
)

# Customize the plot
plt.xlabel('Age')
plt.ylabel('Cholesterol')
plt.title('Age vs Cholesterol colored by Target (Patients > 50)')
plt.colorbar(label='Target')  # shows 0/1 color legend



# Add a meanline
mean_chol = patients_over_50['chol'].mean()
mean_age = patients_over_50['age'].mean()
plt.axhline(mean_chol, color='green', linestyle='--', label='Mean Cholesterol')
plt.axvline(mean_age, color='orange', linestyle='--', label='Mean Age')

plt.legend()
plt.show()

# %% [markdown]
# Wonderful, you've changed the style of the plots and the figure is looking different but the dots aren't a very good colour.
#
# Let's change the `cmap` parameter of `scatter()` as well as the `color` parameter of `axhline()` to fix it.
#
# Completing this step correctly should result in a figure which looks like plot3

# %%
# Replot the same figure as above except change the "cmap" parameter
# of scatter() to "winter"
# Also change the "color" parameter of axhline() to "red"
plt.style.use('seaborn-v0_8-whitegrid')


# Create the plot
plt.figure(figsize=(10, 6))



# Plot the data
plt.scatter(
    patients_over_50['age'],
    patients_over_50['chol'],
    c=patients_over_50['target'],
    cmap='winter',  # Changed cmap to 'winter'
    alpha=0.7
)



# Customize the plot
plt.xlabel('Age')
plt.ylabel('Cholesterol')
plt.title('Age vs Cholesterol colored by Target (Patients > 50)')
plt.colorbar(label='Target')


# Add a meanline
mean_chol = patients_over_50['chol'].mean()
mean_age = patients_over_50['age'].mean()
plt.axhline(mean_chol, color='red', linestyle='--', label='Mean Cholesterol')  # Changed to red
plt.axvline(mean_age, color='orange', linestyle='--', label='Mean Age')

plt.legend()
plt.show()

# %% [markdown]
# Beautiful! Now our figure has an upgraded color scheme let's save it to file.

# %%
# Save the current figure using savefig(), the file name can be anything you want
plt.savefig('age_vs_cholesterol_plot3.png', dpi=300)
plt.show()

# %%
# Reset the figure by calling plt.subplots()
import matplotlib.pyplot as plt

# Reset and start fresh
fig, ax = plt.subplots(figsize=(10, 6))
plt.style.use('seaborn-v0_8-whitegrid')

# Plot the data on the new axes
scatter = ax.scatter(
    patients_over_50['age'],
    patients_over_50['chol'],
    c=patients_over_50['target'],
    cmap='winter',
    alpha=0.7
)

# Customize the plot
ax.set_xlabel('Age')
ax.set_ylabel('Cholesterol')
ax.set_title('Age vs Cholesterol colored by Target (Patients > 50)')

# Add colorbar
cbar = plt.colorbar(scatter, ax=ax)
cbar.set_label('Target')

# Add meanlines
mean_chol = patients_over_50['chol'].mean()
mean_age = patients_over_50['age'].mean()
ax.axhline(mean_chol, color='red', linestyle='--', label='Mean Cholesterol')
ax.axvline(mean_age, color='orange', linestyle='--', label='Mean Age')

# Add legend
ax.legend()

# Show plot
plt.show()

# %%
# Import "../data/heart-disease.csv" and save it to the variable "heart_disease"
import pandas as pd

heart_disease = pd.read_csv("/content/heart-disease (1).csv")

# View the first 10 rows of the heart_disease DataFrame
print(heart_disease.head(10))
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
# 7   0     3       1
# 8   0     3       1
# 9   0     2       1
